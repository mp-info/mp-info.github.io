# %% [markdown]
# # Parcours en largeur
#
# <iframe src=https://mozilla.github.io/pdf.js/web/viewer.html?file=https://raw.githubusercontent.com/mp-info/mp-info.github.io/main/files/2_arbre_graphe/2_parcours/2_bfs.pdf#zoom=page-fit&pagemode=none height=500 width=100% allowfullscreen></iframe>
