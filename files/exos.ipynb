# %% [markdown]
# # Ressources
#
# - [Programme officiel](https://prepas.org/index.php?document=70)
# - [Colles en MPI](https://github.com/fortierq/mpi-colles)
# - [Exercices corrigés en OCaml](https://ocaml.org/problems)
# - [Cours à LLG (**anciens programme**)](https://info-llg.fr)
# - [Cours OCaml à l'université Cornell](https://cs3110.github.io/textbook/cover.html)
# - [Problèmes du projet Euler](https://projecteuler.net/archives)
#
# Pour programmer en OCaml :
# - [Avec Basthon](https://notebook.basthon.fr/ocaml)
# - [En local (Visual Code...)](https://ocaml.org/docs/up-and-running#setting-up-development-tools)
